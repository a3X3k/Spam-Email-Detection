# %%
import pandas as pd

# %%
df=pd.read_csv("3.csv")

# %%
df
# Out:
#                                                    text spam
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0
# 1     martin a posted tassos papadopoulos the greek ...    0
# 2     man threatens explosion in moscow thursday aug...    0
# 3     klez the virus that won t die already the most...    0
# 4      in adding cream to spaghetti carbonara which ...    0
# ...                                                 ...  ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0
# 8247  Subject: industrial worksheets for august 2000...    0
# 8248  Subject: important online banking alert\ndear ...    1
#
# [8249 rows x 2 columns]

# %%
df.dtypes
# Out:
# text    object
# spam    object
# dtype: object

# %%
df.head()
# Out:
#                                                 text spam
# 0   date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0
# 1  martin a posted tassos papadopoulos the greek ...    0
# 2  man threatens explosion in moscow thursday aug...    0
# 3  klez the virus that won t die already the most...    0
# 4   in adding cream to spaghetti carbonara which ...    0

# %%
copy=df
copy
# Out:
#                                                    text spam
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0
# 1     martin a posted tassos papadopoulos the greek ...    0
# 2     man threatens explosion in moscow thursday aug...    0
# 3     klez the virus that won t die already the most...    0
# 4      in adding cream to spaghetti carbonara which ...    0
# ...                                                 ...  ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0
# 8247  Subject: industrial worksheets for august 2000...    0
# 8248  Subject: important online banking alert\ndear ...    1
#
# [8249 rows x 2 columns]

# %%
copy.head()
# Out:
#                                                 text spam
# 0   date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0
# 1  martin a posted tassos papadopoulos the greek ...    0
# 2  man threatens explosion in moscow thursday aug...    0
# 3  klez the virus that won t die already the most...    0
# 4   in adding cream to spaghetti carbonara which ...    0

# %%
copy["text_length"]=copy["text"].str.len()

# %%
copy
# Out:
#                                                    text spam  text_length
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0       1522.0
# 1     martin a posted tassos papadopoulos the greek ...    0        643.0
# 2     man threatens explosion in moscow thursday aug...    0       1509.0
# 3     klez the virus that won t die already the most...    0       1015.0
# 4      in adding cream to spaghetti carbonara which ...    0        771.0
# ...                                                 ...  ...          ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0        522.0
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0       1094.0
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0        390.0
# 8247  Subject: industrial worksheets for august 2000...    0        564.0
# 8248  Subject: important online banking alert\ndear ...    1       1104.0
#
# [8249 rows x 3 columns]

# %%
copy.dtypes
# Out:
# text            object
# spam            object
# text_length    float64
# dtype: object

# %%
df.dropna()
# Out:
#                                                    text spam  text_length
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0       1522.0
# 1     martin a posted tassos papadopoulos the greek ...    0        643.0
# 2     man threatens explosion in moscow thursday aug...    0       1509.0
# 3     klez the virus that won t die already the most...    0       1015.0
# 4      in adding cream to spaghetti carbonara which ...    0        771.0
# ...                                                 ...  ...          ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0        522.0
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0       1094.0
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0        390.0
# 8247  Subject: industrial worksheets for august 2000...    0        564.0
# 8248  Subject: important online banking alert\ndear ...    1       1104.0
#
# [8173 rows x 3 columns]

# %%
copy=copy.dropna()

# %%
copy
# Out:
#                                                    text spam  text_length
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0       1522.0
# 1     martin a posted tassos papadopoulos the greek ...    0        643.0
# 2     man threatens explosion in moscow thursday aug...    0       1509.0
# 3     klez the virus that won t die already the most...    0       1015.0
# 4      in adding cream to spaghetti carbonara which ...    0        771.0
# ...                                                 ...  ...          ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0        522.0
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0       1094.0
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0        390.0
# 8247  Subject: industrial worksheets for august 2000...    0        564.0
# 8248  Subject: important online banking alert\ndear ...    1       1104.0
#
# [8173 rows x 3 columns]

# %%
copy['text_length']=copy['text_length'].astype(int)
# Out:
# <ipython-input-14-bdd5de54b27b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   copy['text_length']=copy['text_length'].astype(int)

# %%
copy.dtypes
# Out:
# text           object
# spam           object
# text_length     int64
# dtype: object

# %%
count_nan = copy['text_length'].isnull().sum()

# %%
count_nan
# Out:
# 0

# %%
copy
# Out:
#                                                    text spam  text_length
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0         1522
# 1     martin a posted tassos papadopoulos the greek ...    0          643
# 2     man threatens explosion in moscow thursday aug...    0         1509
# 3     klez the virus that won t die already the most...    0         1015
# 4      in adding cream to spaghetti carbonara which ...    0          771
# ...                                                 ...  ...          ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0          522
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0         1094
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0          390
# 8247  Subject: industrial worksheets for august 2000...    0          564
# 8248  Subject: important online banking alert\ndear ...    1         1104
#
# [8173 rows x 3 columns]

# %%
import nltk

# %%
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /Users/navneet/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from nltk import word_tokenize

# %%
sw=set(stopwords.words('english'))

# %%
text="i am a good boy or am i".split()
text
# Out:
# ['i', 'am', 'a', 'good', 'boy', 'or', 'am', 'i']

# %%
from nltk import stem
from nltk.corpus import stopwords
stemmer = stem.SnowballStemmer('english')
stopwords = set(stopwords.words('english'))

def alternative_review_messages(msg):
    # converting messages to lowercase
    msg = msg.lower()
    # removing stopwords
    msg = [word for word in msg.split() if word not in stopwords]
    # using a stemmer
    msg = " ".join([stemmer.stem(word) for word in msg])
    return msg

# %%
copy["new_col"]=copy["text"].apply(alternative_review_messages)
# Out:
# <ipython-input-34-ecf532773e2b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   copy["new_col"]=copy["text"].apply(alternative_review_messages)

# %%
copy
# Out:
#                                                    text spam  text_length  \
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0         1522
# 1     martin a posted tassos papadopoulos the greek ...    0          643
# 2     man threatens explosion in moscow thursday aug...    0         1509
# 3     klez the virus that won t die already the most...    0         1015
# 4      in adding cream to spaghetti carbonara which ...    0          771
# ...                                                 ...  ...          ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0          522
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0         1094
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0          390
# 8247  Subject: industrial worksheets for august 2000...    0          564
# 8248  Subject: important online banking alert\ndear ...    1         1104
#
#                                                 new_col
# ...

# %%
copy.head()
# Out:
#                                                 text spam  text_length  \
# 0   date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0         1522
# 1  martin a posted tassos papadopoulos the greek ...    0          643
# 2  man threatens explosion in moscow thursday aug...    0         1509
# 3  klez the virus that won t die already the most...    0         1015
# 4   in adding cream to spaghetti carbonara which ...    0          771
#
#                                              new_col
# 0  date wed number aug number number number numbe...
# 1  martin post tasso papadopoulo greek sculptor b...
# 2  man threaten explos moscow thursday august num...
# 3  klez virus die alreadi prolif virus ever klez ...
# 4  ad cream spaghetti carbonara effect pasta make...

# %%
copy.rename(columns = {'new_col':'cleaned_text'}, inplace = True)
# Out:
# /Users/navneet/Desktop/sample_project/env/lib/python3.9/site-packages/pandas/core/frame.py:5034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
copy
# Out:
#                                                    text spam  text_length  \
# 0      date wed NUMBER aug NUMBER NUMBER NUMBER NUMB...    0         1522
# 1     martin a posted tassos papadopoulos the greek ...    0          643
# 2     man threatens explosion in moscow thursday aug...    0         1509
# 3     klez the virus that won t die already the most...    0         1015
# 4      in adding cream to spaghetti carbonara which ...    0          771
# ...                                                 ...  ...          ...
# 8244  Subject: put the 10 on the ft\nthe transport v...    0          522
# 8245  Subject: 3 / 4 / 2000 and following noms\nhpl ...    0         1094
# 8246  Subject: calpine daily gas nomination\n>\n>\nj...    0          390
# 8247  Subject: industrial worksheets for august 2000...    0          564
# 8248  Subject: important online banking alert\ndear ...    1         1104
#
#                                            cleaned_text
# ...
